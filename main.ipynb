# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import plotly.graph_objects as go

# %%
# Leitura do CSV
df = pd.read_csv('brlbtc.csv')

# %%
# Conversão do tempo de milissegundos para datetime
df['Open time'] = pd.to_datetime(df['Open time'], unit='ms')
df['Close time'] = pd.to_datetime(df['Close time'], unit='ms')

# %%
# Criação dos campos de variação total e variação real
df['Candle_Variation'] = df['High'] - df['Low']
df['Real_Variation'] = df['Close'] - df['Open']

# %%
# Adicionando indicadores de preço
df['SMA'] = ta.sma(df['Close'], length=14)
df['EMA'] = ta.ema(df['Close'], length=14)
df['RSI'] = ta.rsi(df['Close'], length=14)
df['MACD'] = ta.macd(df['Close'])['MACD_12_26_9']
df['Bollinger_Upper'], df['Bollinger_Lower'] = ta.bbands(df['Close'])['BBU_5_2.0'], ta.bbands(df['Close'])['BBL_5_2.0']
df['Parabolic-SAR'] =

# %%
# Adicionando indicadores de volume
df['Volume_SMA'] = ta.sma(df['Volume'], length=14)
df['OBV'] = ta.obv(df['Close'], df['Volume'])

# %%
# Preencher valores NaN
df.fillna(df.mean(), inplace=True)

# %%
# Normalização dos dados
scaler = StandardScaler()
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'Candle_Variation', 'Real_Variation', 'SMA', 'EMA', 'RSI', 'MACD']
df[features] = scaler.fit_transform(df[features])

# %%
# Criando o alvo (target) para classificar (0 = Esperar, 1 = Comprar, 2 = Vender)
df['target'] = 0  # Inicialmente, marcar como "Esperar"
df.loc[df['Close'] > df['SMA'], 'target'] = 1  # Comprar
df.loc[df['Close'] < df['SMA'], 'target'] = 2  # Vender

# %%
# Verificar se o target contém exatamente 3 classes
print("Classes únicas no target antes do balanceamento:", df['target'].unique())
# Out:
# Classes únicas no target antes do balanceamento: [1 2]

# %%
# Definir as variáveis de entrada (X) e saída (y)
X = df[features].values
y = df['target'].values  # Saída agora categórica (0, 1, 2)

# %%
# Balanceamento das classes usando SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# Verificar se o balanceamento incluiu as 3 classes
print("Classes únicas após o balanceamento:", np.unique(y_resampled))
# Out:
# Classes únicas após o balanceamento: [1 2]

# %%
# Divisão dos dados em treino e validação
X_train, X_val, y_train, y_val = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Verificando se ainda temos as 3 classes após a divisão
print("Classes no conjunto de treino:", np.unique(y_train))
print("Classes no conjunto de validação:", np.unique(y_val))
# Out:
# Classes no conjunto de treino: [1 2]
# Classes no conjunto de validação: [1 2]

# %%
# Convertendo a variável target para categórica (one-hot encoding)
from keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=3)  # Precisamos garantir 3 classes
y_val = to_categorical(y_val, num_classes=3)

# %%
# Garantindo que as formas dos dados estejam corretas
print(f"Formato de X_train: {X_train.shape}")
print(f"Formato de y_train: {y_train.shape}")
print(f"Formato de X_val: {X_val.shape}")
print(f"Formato de y_val: {y_val.shape}")
# Out:
# Formato de X_train: (409, 11)
# Formato de y_train: (409, 3)
# Formato de X_val: (103, 11)
# Formato de y_val: (103, 3)

# %%
# Arquitetura da rede neural ajustada
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))  # Dropout para regularização
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))  # Mais Dropout
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))  # Saída para 3 classes (comprar, vender, esperar)
# Out:
# C:\Users\Mariano\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
# Compilação do modelo
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinamento do modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1565 - loss: 1.1932 - val_accuracy: 0.7087 - val_loss: 0.9451
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7397 - loss: 0.8978 - val_accuracy: 0.8058 - val_loss: 0.7110
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8249 - loss: 0.6873 - val_accuracy: 0.8835 - val_loss: 0.4607
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - loss: 0.4713 - val_accuracy: 0.8835 - val_loss: 0.3291
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.3855 - val_accuracy: 0.8641 - val_loss: 0.2697
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8637 - loss: 0.3077 - val_accuracy: 0.9029 - val_loss: 0.2360
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8991 - loss: 0.2421 - val_accuracy: 0.9029 - val_loss: 0.2124
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8830 - loss: 0.2487 - val_accuracy: 0.9029 - val_loss: 0.1937
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9002 - loss: 0.2486 - val_accuracy: 0.9417 - val_loss: 0.1772
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9465 - loss: 0.1674 - val_accuracy: 0.9320 - val_loss: 0.1651
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9289 - loss: 0.1552 - val_accuracy: 0.9223 - val_loss: 0.1641
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9094 - loss: 0.2113 - val_accuracy: 0.9515 - val_loss: 0.1680
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.1703 - val_accuracy: 0.9320 - val_loss: 0.1691
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9202 - loss: 0.1677 - val_accuracy: 0.9417 - val_loss: 0.1492
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9366 - loss: 0.1523 - val_accuracy: 0.9223 - val_loss: 0.1511
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9149 - loss: 0.1613 - val_accuracy: 0.9515 - val_loss: 0.1341
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9426 - loss: 0.1266 - val_accuracy: 0.9320 - val_loss: 0.1530
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9487 - loss: 0.1156 - val_accuracy: 0.9320 - val_loss: 0.1478
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9520 - loss: 0.1320 - val_accuracy: 0.9417 - val_loss: 0.1632
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9649 - loss: 0.0889 - val_accuracy: 0.9417 - val_loss: 0.1440
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9384 - loss: 0.1387 - val_accuracy: 0.9320 - val_loss: 0.1482
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.1194 - val_accuracy: 0.9515 - val_loss: 0.1388
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9289 - loss: 0.1482 - val_accuracy: 0.9417 - val_loss: 0.1507
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9467 - loss: 0.1086 - val_accuracy: 0.9515 - val_loss: 0.1439
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9242 - loss: 0.1258 - val_accuracy: 0.9515 - val_loss: 0.1485
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9528 - loss: 0.1090 - val_accuracy: 0.9320 - val_loss: 0.1611
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.0865 - val_accuracy: 0.9417 - val_loss: 0.1569
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.0996 - val_accuracy: 0.9417 - val_loss: 0.1562
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.0817 - val_accuracy: 0.9320 - val_loss: 0.1643
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9662 - loss: 0.0976 - val_accuracy: 0.9612 - val_loss: 0.1453
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.1055 - val_accuracy: 0.9417 - val_loss: 0.1563
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.1259 - val_accuracy: 0.9320 - val_loss: 0.1657
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.0995 - val_accuracy: 0.9417 - val_loss: 0.1578
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9661 - loss: 0.0691 - val_accuracy: 0.9320 - val_loss: 0.1670
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9569 - loss: 0.0840 - val_accuracy: 0.9515 - val_loss: 0.1642
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9641 - loss: 0.0778 - val_accuracy: 0.9515 - val_loss: 0.1614
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9564 - loss: 0.1005 - val_accuracy: 0.9515 - val_loss: 0.1390
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.0665 - val_accuracy: 0.9320 - val_loss: 0.1651
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9789 - loss: 0.0850 - val_accuracy: 0.9417 - val_loss: 0.1752
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9819 - loss: 0.0694 - val_accuracy: 0.9223 - val_loss: 0.1757
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0596 - val_accuracy: 0.9126 - val_loss: 0.1682
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.0675 - val_accuracy: 0.9417 - val_loss: 0.1556
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9488 - loss: 0.0890 - val_accuracy: 0.9223 - val_loss: 0.1760
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.0898 - val_accuracy: 0.9126 - val_loss: 0.1944
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9699 - loss: 0.0837 - val_accuracy: 0.9417 - val_loss: 0.1655
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0552 - val_accuracy: 0.9417 - val_loss: 0.1621
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.0602 - val_accuracy: 0.9515 - val_loss: 0.1627
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9627 - loss: 0.0902 - val_accuracy: 0.9320 - val_loss: 0.1701
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0623 - val_accuracy: 0.9320 - val_loss: 0.1808
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9693 - loss: 0.0682 - val_accuracy: 0.9320 - val_loss: 0.2045

# %%
# Avaliação do modelo
y_pred = model.predict(X_val)
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/stepWARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F8BFEB2FC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# Conversão das predições para rótulos
y_pred_classes = np.argmax(y_pred, axis=1)
y_val_classes = np.argmax(y_val, axis=1)

# %%
# Cálculo das métricas
rmse = np.sqrt(mean_squared_error(y_val_classes, y_pred_classes))
mae = mean_absolute_error(y_val_classes, y_pred_classes)
r2 = r2_score(y_val_classes, y_pred_classes)
accuracy = accuracy_score(y_val_classes, y_pred_classes)
precision = precision_score(y_val_classes, y_pred_classes, average='macro')
recall = recall_score(y_val_classes, y_pred_classes, average='macro')
f1 = f1_score(y_val_classes, y_pred_classes, average='macro')

# %%
# Exibindo as métricas
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R²: {r2}")
print(f"Acurácia: {accuracy}")
print(f"Precisão: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
# Out:
# RMSE: 0.2606936229533505
# MAE: 0.06796116504854369
# R²: 0.7275132275132274
# Acurácia: 0.9320388349514563
# Precisão: 0.9316981132075473
# Recall: 0.9323507180650038
# F1-Score: 0.9319361842726328

# %%
# Matriz de Confusão
conf_matrix = confusion_matrix(y_val_classes, y_pred_classes)
print(f"Matriz de Confusão:\n{conf_matrix}")
# Out:
# Matriz de Confusão:
# [[46  3]
#  [ 4 50]]

# %%
# Gráfico dos candles e indicadores usando Plotly
fig = go.Figure(data=[go.Candlestick(x=df['Open time'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

# %%
# Adicionando médias móveis
fig.add_trace(go.Scatter(x=df['Open time'], y=df['SMA'], mode='lines', name='SMA'))
fig.add_trace(go.Scatter(x=df['Open time'], y=df['EMA'], mode='lines', name='EMA'))

fig.update_layout(title='Candlestick com SMA e EMA', xaxis_title='Tempo', yaxis_title='Preço')
fig.show()
# Out:
# <div>                            <div id="9e32105a-b79c-4fa8-948b-e3e7abdf9782" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e32105a-b79c-4fa8-948b-e3e7abdf9782")) {                    Plotly.newPlot(                        "9e32105a-b79c-4fa8-948b-e3e7abdf9782",                        [{"close":[3.1419879409019327,2.806934687774291,2.601648091413545,2.422953023078803,2.3958296644922794,2.688336472778316,2.4522037039074065,2.047480647351636,1.527882189723531,1.35929190203867,1.6938133246057918,1.3576964103571099,1.0380662434845498,0.5615460612585703,0.4493298129888363,0.8178883914292423,0.9391457592278175,0.5381455165956874,-0.5021150597815626,0.2057514162706459,0.019610720088622625,-0.8153632599278817,0.1626731408685205,0.16958693815528136,0.6758896317703846,0.3557276343373046,-0.16599814553288056,0.35147298985314407,-0.3271428053704607,-0.3750075558172667,-0.1888668596352434,-0.5414705212600475,-1.0786193873853145,-1.0392639259068297,-1.3993132153789145,-0.32129266920474,-0.4489320037295559,0.28871698371177623,-0.47180071783191874,-0.37819853918038704,-0.15057505927779863,-0.8791829271902897,-0.7334613536077914,-0.6850647726004654,-0.2649186297896129,-0.1840803845905628,-0.042613455492225144,0.25414799727797194,0.2073469079522061,0.2610617945647328,0.16160947974748036,0.4652847298044383,0.5700553502268914,0.39933774029995006,0.7476867574405935,0.2839305086670956,0.1387407656451175,0.3690233983503063,0.3248814618271408,-0.12717451461491572,-0.2755552410000142,-0.5547662852730492,-0.6925104004477464,-0.8509959074827261,-1.1397799018451222,-1.2445505222675752,-1.0302228063779886,-0.6382636832746995,-0.6372000221536595,-0.9291749998791758,-1.0967016264429967,-1.1738170577184064,-1.3503848038110684,-1.4844061050621253,-1.6694831401231083,-1.8008452885715647,-1.5657761808216955,-1.4360095240547992,-1.6471462565812656,-1.507274819164488,-1.8300959694001684,-1.5211024137380098,-1.5157841081328092,-1.8242458332344478,-1.7896768468006434,-1.9901769681167085,-2.40181382195924,-2.459783353055927,-2.5368987843313366,-2.2683243512687032,-2.123134608246725,-1.4227137600417976,-1.4211182683602372,-1.4535599325519615,-1.2652919141278578,-1.2855014754276204,-1.225936452649373,-1.2222136387257325,-1.033945620301629,-0.8664189937378081,-1.0403275870278699,-1.1339297656794014,-1.2200863164836522,-0.9079017774583732,-0.9105609302609735,-0.5973127301146545,-0.42872244242979335,-0.5691257104070909,-0.6590050751349822,-0.5005195681000023,-0.7355886758498718,-0.6361363610326193,-0.505306043144683,-0.6159267997328568,-0.5925262550699738,-0.762180203875875,-0.8424866185144051,-0.5164744849156043,-0.47977817623971974,-0.6877239254030657,-0.5542344547125291,-0.8424866185144051,-0.8222770572146425,-0.5132835015524839,-0.5850806272226929,-0.42872244242979335,-0.4281906118692733,0.028651839617463756,-0.034104166523904085,-0.12983366741751604,-0.3521388417149038,-0.3569253167595844,-0.23460428783996912,0.08289855679051053,0.03131099242006409,-0.25640934082129185,-0.25640934082129185,-0.31331521079693897,-0.14206577030947756,-0.22024486270592733,0.005251294954580832,0.12757232387419612,0.22702463869144854,-0.13727929526479696,-0.39787626991962954,-0.5999718829172548,0.09832164304559246,0.21904718028364753,0.3759371956370671,-0.014958266345181692,-0.028254030358183354,-0.377666708619867,-0.10696495331515318,-0.19312150411940396,-0.17769841786432203,0.010569600559781496,-0.13568380358323678,0.02918367017798382,0.09991713472715266,0.12757232387419612,0.25840264176213246,0.278612203061895,0.3812555012422678,0.35040932873210395,0.3307315979928615,0.3860419762869484,0.6062198283422559,0.48868527446732124,0.6290885424446188,0.8216112053528828,0.9556325066039395,1.2194204646218925,1.1002904190653977,1.1805968337039277,1.35982373 ...
